# %% [markdown]
# <a href="https://colab.research.google.com/github/kanika204/FloraNourish/blob/main/WeatherConditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

os.environ["KAGGLE_USERNAME"] = "kanakgoyal01"
os.environ["KAGGLE_KEY"] = "f58621c1b27a7a854dd808e2b036c366"
# !pip install kaggle

# %%
# !kaggle datasets download -d atharvaingle/crop-recommendation-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/atharvaingle/crop-recommendation-dataset
# License(s): apache-2.0
# ...
# 100% 63.7k/63.7k [00:00<00:00, 47.5MB/s]

# %%
import zipfile

with zipfile.ZipFile('crop-recommendation-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
import pandas as pd

data = pd.read_csv("Crop_recommendation.csv")
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X = data.drop("label", axis=1)
y = data["label"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestClassifier()
model.fit(X_train, y_train)

print("Model trained successfully ✅")
# Out:
# Model trained successfully ✅

# %%
data.shape
# Out:
# (2200, 8)

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9931818181818182
