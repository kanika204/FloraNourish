# %% [markdown]
# <a href="https://colab.research.google.com/github/kanika204/FloraNourish/blob/main/PlantIdentification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

os.environ["KAGGLE_USERNAME"] = "kanakgoyal01"
os.environ["KAGGLE_KEY"] = "f58621c1b27a7a854dd808e2b036c366"
# !pip install kaggle

# %%
# !kaggle datasets download -d marquis03/plants-classification
# Out:
# Dataset URL: https://www.kaggle.com/datasets/marquis03/plants-classification
# License(s): apache-2.0
# ...
# 100% 1.34G/1.34G [00:10<00:00, 140MB/s]

# %%
import zipfile

with zipfile.ZipFile('plants-classification.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'test.csv',
#  'test',
#  'val',
#  'train',
#  'plants-classification.zip',
#  'train.csv',
#  'val.csv',
#  'sample_data']

# %%
data_dir = "train"

# %%
import tensorflow as tf

train_data = tf.keras.preprocessing.image_dataset_from_directory(
    "train",
    image_size=(224, 224),
    batch_size=32
)

val_data = tf.keras.preprocessing.image_dataset_from_directory(
    "val",
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 21000 files belonging to 30 classes.
# Found 3000 files belonging to 30 classes.

# %%
class_names = train_data.class_names
num_classes = len(class_names)

print("Classes:", class_names)
# Out:
# Classes: ['aloevera', 'banana', 'bilimbi', 'cantaloupe', 'cassava', 'coconut', 'corn', 'cucumber', 'curcuma', 'eggplant', 'galangal', 'ginger', 'guava', 'kale', 'longbeans', 'mango', 'melon', 'orange', 'paddy', 'papaya', 'peperchili', 'pineapple', 'pomelo', 'shallot', 'soybeans', 'spinach', 'sweetpotatoes', 'tobacco', 'waterapple', 'watermelon']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_data = train_data.prefetch(buffer_size=AUTOTUNE)
val_data = val_data.prefetch(buffer_size=AUTOTUNE)

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224,224,3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = False
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras import layers, models

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 66s 86ms/step - accuracy: 0.2557 - loss: 2.6525 - val_accuracy: 0.3400 - val_loss: 2.2658
# Epoch 2/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 43s 65ms/step - accuracy: 0.3697 - loss: 2.1846 - val_accuracy: 0.4100 - val_loss: 2.0441
# Epoch 3/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 48s 72ms/step - accuracy: 0.4173 - loss: 2.0033 - val_accuracy: 0.4390 - val_loss: 1.9801
# Epoch 4/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 78s 67ms/step - accuracy: 0.4532 - loss: 1.8694 - val_accuracy: 0.4543 - val_loss: 1.9014
# Epoch 5/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 42s 64ms/step - accuracy: 0.4827 - loss: 1.7601 - val_accuracy: 0.4503 - val_loss: 1.9333
# Epoch 6/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 83s 66ms/step - accuracy: 0.5079 - loss: 1.6693 - val_accuracy: 0.4693 - val_loss: 1.8669
# Epoch 7/10
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 82s 66ms/step - accuracy: 0.5242 - loss: 1.5957 - val_accuracy: 0.4847 - val_loss: 1.8284
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(val_data)
print("Validation Accuracy:", accuracy)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.4900 - loss: 1.8438
# Validation Accuracy: 0.49000000953674316
